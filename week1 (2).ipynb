# %%
import pandas as pd
df=pd.read_csv('C:\\Users\\y20cs74\\Desktop\\project_data.csv')
df
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 0       20201701            1982        Graduation         Single
# 1       20201702            1950        Graduation        Married
# 2       20201703            1965        Graduation       Divorced
# 3       20201704            1984        Graduation   Relationship
# 4       20201705            1981               PhD        Widowed
# ..           ...             ...               ...            ...
# 495     20202196            1962            Master       Divorced
# 496     20202197            1978        Graduation       Divorced
# 497     20202198            1971               PhD   Relationship
# 498     20202199            1949               PhD   Relationship
# 499     20202199            1949               PhD   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0          58138.0      9/4/2012       58                 8                4
# ...

# %%
#2a.
df.iloc[:5]
#df.head()
# Out:
#    customer_id  year_of_birth  educational_level marital_status  \
# 0     20201701            1982        Graduation         Single
# 1     20201702            1950        Graduation        Married
# 2     20201703            1965        Graduation       Divorced
# 3     20201704            1984        Graduation   Relationship
# 4     20201705            1981               PhD        Widowed
#
#    annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0        58138.0      9/4/2012       58                 8                4
# 1        46344.0      3/8/2014       38                 1                2
# 2        71613.0     8/21/2013       26                 8               10
# 3        26646.0     2/10/2014       26                 2                4
# 4        58293.0     1/19/2014       94                 5                6
#
#    complaints  calls  intercoms
# 0           0      3         11
# 1           0      3         11
# ...

# %%
df.iloc[-5:]
#df.tail()
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 495     20202196            1962            Master       Divorced
# 496     20202197            1978        Graduation       Divorced
# 497     20202198            1971               PhD   Relationship
# 498     20202199            1949               PhD   Relationship
# 499     20202199            1949               PhD   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 495        59432.0     4/13/2013       88                 5               11
# 496        55563.0      4/5/2014       22                 2                3
# 497        43624.0     4/21/2013       83                 4                4
# 498        41461.0     5/22/2014       63                 6               11
# 499        41461.0     5/22/2014       63                 6               11
#
#      complaints  calls  intercoms
# 495           0      3         11
# 496           0      3         11
# ...

# %%
#b.
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        500 non-null    int64
#  1   year_of_birth      500 non-null    int64
#  2   educational_level  500 non-null    object
#  3   marital_status     500 non-null    object
#  4   annual_income      487 non-null    float64
#  5   purhcase_date      500 non-null    object
#  6   recency            500 non-null    int64
#  7   online_purchases   500 non-null    int64
#  8   store_purchases    500 non-null    int64
#  9   complaints         500 non-null    int64
#  10  calls              500 non-null    int64
#  11  intercoms          500 non-null    int64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 47.0+ KB
# None

# %%
#c.
df.shape
# Out:
# (500, 12)

# %%
#d
df['marital_status'].unique()
# Out:
# array(['Single', 'Married', 'Divorced', 'Relationship', 'Widowed',
#        'Widow'], dtype=object)

# %%
#e.
df['marital_status'].replace('Widowed','Widow')
# Out:
# 0            Single
# 1           Married
# 2          Divorced
# 3      Relationship
# 4             Widow
#            ...
# 495        Divorced
# 496        Divorced
# 497    Relationship
# 498    Relationship
# 499    Relationship
# Name: marital_status, Length: 500, dtype: object

# %%
#f.
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499     True
# Length: 500, dtype: bool

# %%
df.isnull()
# Out:
#      customer_id  year_of_birth   educational_level  marital_status  \
# 0          False           False              False           False
# 1          False           False              False           False
# 2          False           False              False           False
# 3          False           False              False           False
# 4          False           False              False           False
# ..           ...             ...                ...             ...
# 495        False           False              False           False
# 496        False           False              False           False
# 497        False           False              False           False
# 498        False           False              False           False
# 499        False           False              False           False
#
#      annual_income  purhcase_date  recency  online_purchases  store_purchases  \
# ...

# %%
#3.a.
df[['year_of_birth ','educational_level','annual_income']]
# Out:
#      year_of_birth  educational_level  annual_income
# 0              1982        Graduation        58138.0
# 1              1950        Graduation        46344.0
# 2              1965        Graduation        71613.0
# 3              1984        Graduation        26646.0
# 4              1981               PhD        58293.0
# ..              ...               ...            ...
# 495            1962            Master        59432.0
# 496            1978        Graduation        55563.0
# 497            1971               PhD        43624.0
# 498            1949               PhD        41461.0
# 499            1949               PhD        41461.0
#
# [500 rows x 3 columns]

# %%
#b.
df.loc[0:6]
# Out:
#    customer_id  year_of_birth  educational_level marital_status  \
# 0     20201701            1982        Graduation         Single
# 1     20201702            1950        Graduation        Married
# 2     20201703            1965        Graduation       Divorced
# 3     20201704            1984        Graduation   Relationship
# 4     20201705            1981               PhD        Widowed
# 5     20201706            1967            Master   Relationship
# 6     20201707            1971        Graduation       Divorced
#
#    annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0        58138.0      9/4/2012       58                 8                4
# 1        46344.0      3/8/2014       38                 1                2
# 2        71613.0     8/21/2013       26                 8               10
# 3        26646.0     2/10/2014       26                 2                4
# 4        58293.0     1/19/2014       94                 5                6
# ...

# %%
df.iloc[0:7,]
# Out:
#    customer_id  year_of_birth  educational_level marital_status  \
# 0     20201701            1982        Graduation         Single
# 1     20201702            1950        Graduation        Married
# 2     20201703            1965        Graduation       Divorced
# 3     20201704            1984        Graduation   Relationship
# 4     20201705            1981               PhD        Widowed
# 5     20201706            1967            Master   Relationship
# 6     20201707            1971        Graduation       Divorced
#
#    annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0        58138.0      9/4/2012       58                 8                4
# 1        46344.0      3/8/2014       38                 1                2
# 2        71613.0     8/21/2013       26                 8               10
# 3        26646.0     2/10/2014       26                 2                4
# 4        58293.0     1/19/2014       94                 5                6
# ...

# %%
#c.
df.loc[(df['annual_income']<50000) & (df['recency'].isin([38,58,26]))]
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 1       20201702            1950        Graduation        Married
# 3       20201704            1984        Graduation   Relationship
# 14      20201715            1987        Graduation        Married
# 28      20201729            1989        Graduation         Single
# 74      20201775            1991        Graduation         Single
# 170     20201871            1985        Graduation   Relationship
# 274     20201975            1963        Graduation         Single
# 380     20202081            1992               PhD        Widowed
# 474     20202175            1988        Graduation         Single
# 482     20202183            1974        Graduation         Single
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 1          46344.0      3/8/2014       38                 1                2
# 3          26646.0     2/10/2014       26                 2                4
# ...

# %%
#d.
df[(df['annual_income']>75000) & (df['educational_level'].isin(['Master']))]
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 18      20201719            1980            Master         Single
# 51      20201752            1964            Master         Single
# 55      20201756            1955            Master        Married
# 60      20201761            1982            Master         Single
# 76      20201777            1993            Master        Married
# 109     20201810            1993            Master         Single
# 120     20201821            1957            Master   Relationship
# 140     20201841            1987            Master         Single
# 217     20201918            1985            Master        Widowed
# 277     20201978            1981            Master         Single
# 305     20202006            1983            Master        Widowed
# 423     20202124            1973            Master   Relationship
# 435     20202136            1983            Master   Relationship
#
# ...

# %%
#4.a.
df.set_index('customer_id')
# Out:
#              year_of_birth  educational_level marital_status  annual_income  \
# customer_id
# 20201701               1982        Graduation         Single        58138.0
# 20201702               1950        Graduation        Married        46344.0
# 20201703               1965        Graduation       Divorced        71613.0
# 20201704               1984        Graduation   Relationship        26646.0
# 20201705               1981               PhD        Widowed        58293.0
# ...                     ...               ...            ...            ...
# 20202196               1962            Master       Divorced        59432.0
# 20202197               1978        Graduation       Divorced        55563.0
# 20202198               1971               PhD   Relationship        43624.0
# 20202199               1949               PhD   Relationship        41461.0
# 20202199               1949               PhD   Relationship        41461.0
#
# ...

# %%
#b.
df.sort_values(by=['purhcase_date','customer_id'])
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 48      20201749            1951        Graduation        Married
# 460     20202161            1957        Graduation        Married
# 333     20202034            1971            Master   Relationship
# 351     20202052            1986        Graduation         Single
# 324     20202025            1980        Graduation        Married
# ..           ...             ...               ...            ...
# 454     20202155            1974        Graduation        Married
# 437     20202138            1985            Master          Widow
# 224     20201925            1992        Graduation        Widowed
# 190     20201891            1973             Basic         Single
# 5       20201706            1967            Master   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 48             NaN      1/1/2014       96                 2                4
# ...

# %%
#c.
df['sum']=df[['online_purchases','store_purchases']].sum(axis=1)
df
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 0       20201701            1982        Graduation         Single
# 1       20201702            1950        Graduation        Married
# 2       20201703            1965        Graduation       Divorced
# 3       20201704            1984        Graduation   Relationship
# 4       20201705            1981               PhD        Widowed
# ..           ...             ...               ...            ...
# 495     20202196            1962            Master       Divorced
# 496     20202197            1978        Graduation       Divorced
# 497     20202198            1971               PhD   Relationship
# 498     20202199            1949               PhD   Relationship
# 499     20202199            1949               PhD   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0          58138.0      9/4/2012       58                 8                4
# ...

# %%
#d
pd.to_datetime(df['purhcase_date'])
# Out:
# 0     2012-09-04
# 1     2014-03-08
# 2     2013-08-21
# 3     2014-02-10
# 4     2014-01-19
#          ...
# 495   2013-04-13
# 496   2014-04-05
# 497   2013-04-21
# 498   2014-05-22
# 499   2014-05-22
# Name: purhcase_date, Length: 500, dtype: datetime64[ns]

# %%
#e
d=int(pd.to_datetime("today").strftime("%Y"))
df['age']=d-df['year_of_birth ']
df[['customer_id','age']]
# Out:
#      customer_id  age
# 0       20201701   40
# 1       20201702   72
# 2       20201703   57
# 3       20201704   38
# 4       20201705   41
# ..           ...  ...
# 495     20202196   60
# 496     20202197   44
# 497     20202198   51
# 498     20202199   73
# 499     20202199   73
#
# [500 rows x 2 columns]

# %%
#f
df['purchase_date']=pd.to_datetime(df['purhcase_date'])
df['week']=df['purchase_date'].dt.strftime('%U')
df[['purchase_date','week']]
# Out:
#     purchase_date week
# 0      2012-09-04   36
# 1      2014-03-08   09
# 2      2013-08-21   33
# 3      2014-02-10   06
# 4      2014-01-19   03
# ..            ...  ...
# 495    2013-04-13   14
# 496    2014-04-05   13
# 497    2013-04-21   16
# 498    2014-05-22   20
# 499    2014-05-22   20
#
# [500 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        500 non-null    int64
#  1   year_of_birth      500 non-null    int64
#  2   educational_level  500 non-null    object
#  3   marital_status     500 non-null    object
#  4   annual_income      487 non-null    float64
#  5   purhcase_date      500 non-null    object
#  6   recency            500 non-null    int64
#  7   online_purchases   500 non-null    int64
#  8   store_purchases    500 non-null    int64
#  9   complaints         500 non-null    int64
#  10  calls              500 non-null    int64
#  11  intercoms          500 non-null    int64
#  12  sum                500 non-null    int64
#  13  age                500 non-null    int64
#  14  purchase_date      500 non-null    datetime64[ns]
# ...
